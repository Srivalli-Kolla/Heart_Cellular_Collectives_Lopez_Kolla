# %% [markdown]
# # Notebook to download Human heart data from 'CellxGene'
#
# **Developed by** :Srivalli Kolla
#
# **Created on** : 23 October , 2024
#
# **Last modified** : 23 October, 2024
#
# **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**

# %% [markdown]
# Link : https://cellxgene.cziscience.com/datasets

# %% [markdown]
# Env : cellxgene (Python 3.10)

# %% [markdown]
# # Importing packages

# %%
import cellxgene_census
import numpy as np
import pandas as pd
import scanpy as sc
import os
from datetime import datetime

timestamp = datetime.now().strftime("%d_%m_%Y")

# %% [markdown]
# # Data import and overview

# %% [markdown]
# ## Query to check the census about dataset required

# %%
census = cellxgene_census.open_soma()
summary_table = census["census_info"]["summary_cell_counts"].read().concat().to_pandas()

summary_table.query("organism == 'Homo sapiens' & category == 'tissue_general' & label =='heart'")
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.
#       soma_joinid      organism        category  label ontology_term_id  \
# 1147         1147  Homo sapiens  tissue_general  heart   UBERON:0000948
#
#       total_cell_count  unique_cell_count
# 1147           3629952            1559974

# %% [markdown]
# ## Loading data from census

# %%
heart_obs =  cellxgene_census.get_obs(
    census, "homo_sapiens", value_filter="tissue_general == 'heart' and is_primary_data == True" )
heart_obs
# Out:
#          soma_joinid                            dataset_id        assay  \
# 0            1702855  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 1            1702856  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 2            1702857  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 3            1702858  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 4            1702859  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# ...              ...                                   ...          ...
# 1559969     66344455  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559970     66344456  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559971     66344457  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559972     66344458  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559973     66344459  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
#
#         assay_ontology_term_id                          cell_type  \
# 0                  EFO:0009922      immature innate lymphoid cell
# 1                  EFO:0009922       fibroblast of cardiac tissue
# 2                  EFO:0009922       fibroblast of cardiac tissue
# 3                  EFO:0009922      immature innate lymphoid cell
# 4                  EFO:0009922            cardiac muscle myoblast
# ...                        ...                                ...
# 1559969            EFO:0010550                cardiac muscle cell
# 1559970            EFO:0010550                cardiac muscle cell
# 1559971            EFO:0010550                cardiac muscle cell
# 1559972            EFO:0010550  endothelial cell of vascular tree
# 1559973            EFO:0010550                cardiac muscle cell
#
#         cell_type_ontology_term_id                         development_stage  \
# 0                       CL:0001082                   61-year-old human stage
# 1                       CL:0002548                   61-year-old human stage
# 2                       CL:0002548                   61-year-old human stage
# 3                       CL:0001082                   61-year-old human stage
# 4                       CL:0000513                   61-year-old human stage
# ...                            ...                                       ...
# 1559969                 CL:0000746  12th week post-fertilization human stage
# 1559970                 CL:0000746  12th week post-fertilization human stage
# 1559971                 CL:0000746  12th week post-fertilization human stage
# 1559972                 CL:0002139  12th week post-fertilization human stage
# 1559973                 CL:0000746  12th week post-fertilization human stage
#
#         development_stage_ontology_term_id                disease  \
# 0                           HsapDv:0000155  myocardial infarction
# 1                           HsapDv:0000155  myocardial infarction
# 2                           HsapDv:0000155  myocardial infarction
# 3                           HsapDv:0000155  myocardial infarction
# 4                           HsapDv:0000155  myocardial infarction
# ...                                    ...                    ...
# 1559969                     HsapDv:0000049                 normal
# 1559970                     HsapDv:0000049                 normal
# 1559971                     HsapDv:0000049                 normal
# 1559972                     HsapDv:0000049                 normal
# 1559973                     HsapDv:0000049                 normal
#
#         disease_ontology_term_id  ...                tissue  \
# 0                  MONDO:0005068  ...  heart left ventricle
# 1                  MONDO:0005068  ...  heart left ventricle
# 2                  MONDO:0005068  ...  heart left ventricle
# 3                  MONDO:0005068  ...  heart left ventricle
# 4                  MONDO:0005068  ...  heart left ventricle
# ...                          ...  ...                   ...
# 1559969             PATO:0000461  ...                 heart
# 1559970             PATO:0000461  ...                 heart
# 1559971             PATO:0000461  ...                 heart
# 1559972             PATO:0000461  ...                 heart
# 1559973             PATO:0000461  ...                 heart
#
#          tissue_ontology_term_id tissue_type tissue_general  \
# 0                 UBERON:0002084      tissue          heart
# 1                 UBERON:0002084      tissue          heart
# 2                 UBERON:0002084      tissue          heart
# 3                 UBERON:0002084      tissue          heart
# 4                 UBERON:0002084      tissue          heart
# ...                          ...         ...            ...
# 1559969           UBERON:0000948      tissue          heart
# 1559970           UBERON:0000948      tissue          heart
# 1559971           UBERON:0000948      tissue          heart
# 1559972           UBERON:0000948      tissue          heart
# 1559973           UBERON:0000948      tissue          heart
#
#         tissue_general_ontology_term_id raw_sum   nnz raw_mean_nnz  \
# 0                        UBERON:0000948  4190.0  2093     2.001911
# 1                        UBERON:0000948  6506.0  2750     2.365818
# 2                        UBERON:0000948  2462.0  1420     1.733803
# 3                        UBERON:0000948  1524.0  1067     1.428304
# 4                        UBERON:0000948  6199.0  2001     3.097951
# ...                                 ...     ...   ...          ...
# 1559969                  UBERON:0000948   633.0   485     1.305155
# 1559970                  UBERON:0000948   502.0   349     1.438395
# 1559971                  UBERON:0000948   459.0   364     1.260989
# 1559972                  UBERON:0000948   247.0   220     1.122727
# 1559973                  UBERON:0000948   347.0   276     1.257246
#
#         raw_variance_nnz n_measured_vars
# 0              12.914910           20691
# 1              41.999268           20691
# 2              23.365312           20691
# 3               3.061224           20691
# 4             387.196401           20691
# ...                  ...             ...
# 1559969         1.369498           44067
# 1559970         1.953809           44067
# 1559971         0.964755           44067
# 1559972         0.190349           44067
# 1559973         0.824493           44067
#
# [1559974 rows x 28 columns]

# %% [markdown]
# ## Data overview

# %%
heart_obs['soma_joinid'].value_counts()
# Out:
# soma_joinid
# 66344459    1
# 1702855     1
# 1702856     1
# 1702857     1
# 1702858     1
#            ..
# 1702864     1
# 1702865     1
# 1702866     1
# 1702867     1
# 1702868     1
# Name: count, Length: 1559974, dtype: int64

# %%
heart_obs['dataset_id'].value_counts()
# Out:
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039    665955
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e    486134
# 1c739a3e-c3f5-49d5-98e0-73975e751201    191795
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353    101749
# 4ed927e9-c099-49af-b8ce-a2652d069333     36574
#                                          ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2         0
# 5829c7ba-697f-418e-8b98-d605b192dc48         0
# 58679288-9ecc-4647-9781-12a3a8f8c6fd         0
# 58c43cc2-e00e-43c4-94eb-8501369264e1         0
# 53bc5729-6202-4351-bc99-1f36139e9dc4         0
# Name: count, Length: 678, dtype: int64

# %%
heart_obs['dataset_id'].unique()
# Out:
# ['f15e263b-6544-46cb-a46e-e33ab7ce8347', '5500c673-1610-40a0-86d9-64d987ae50e6', '2adb1f8a-a6b1-4909-8ee8-484814e2d4bf', '4ed927e9-c099-49af-b8ce-a2652d069333', '1c739a3e-c3f5-49d5-98e0-73975e751201', 'd4e69e01-3ba2-4d6b-a15d-e7048f78f22e', 'd567b692-c374-4628-a508-8008f6778f22', '65badd7a-9262-4fd1-9ce2-eb5dc0ca8039', '53d208b0-2cfd-4366-9866-c3c6114081bc', 'f7c1c579-2dc0-47e2-ba19-8165c5a0e353']
# Categories (678, object): ['0041b9c3-6a49-4bf7-8514-9bc7190067a7', '00476f9f-ebc1-4b72-b541-32f912ce36ea', '00e5dedd-b9b7-43be-8c28-b0e5c6414a62', '00ff600e-6e2e-4d76-846f-0eec4f0ae417', ..., 'fe4b89d5-461e-440c-a5a8-621b37b122c0', 'fe52003e-1460-4a65-a213-2bb1a508332f', 'ff45e623-7f5f-46e3-b47d-56be0341f66b', 'ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded']

# %%
heart_obs['assay'].unique()
# Out:
# ['10x 3' v3', '10x 3' v2', 'microwell-seq', 'Smart-seq2', 'sci-RNA-seq']
# Categories (24, object): ['10x 3' transcription profiling', '10x 3' v1', '10x 3' v2', '10x 3' v3', ..., 'TruDrop', 'inDrop', 'microwell-seq', 'sci-RNA-seq']

# %%
heart_obs['disease'].unique()
# Out:
# ['myocardial infarction', 'normal', 'dilated cardiomyopathy', 'arrhythmogenic right ventricular cardiomyopathy', 'non-compaction cardiomyopathy']
# Categories (109, object): ['Alzheimer disease', 'B-cell acute lymphoblastic leukemia', 'B-cell non-Hodgkin lymphoma', 'Barrett esophagus', ..., 'tubular adenoma', 'tubulovillous adenoma', 'type 1 diabetes mellitus', 'type 2 diabetes mellitus']

# %%
heart_obs[["suspension_type"]].value_counts()
# Out:
# suspension_type
# nucleus            1375447
# cell                184527
# Name: count, dtype: int64

# %%
heart_obs[["cell_type"]].value_counts()
# Out:
# cell_type
# cardiac muscle cell                        284321
# fibroblast of cardiac tissue               170070
# mural cell                                 128390
# regular ventricular cardiac myocyte        125289
# endothelial cell                           118837
#                                             ...
# enteroendocrine cell of colon                   0
# enteroendocrine cell of small intestine         0
# enucleate erythrocyte                           0
# enucleated reticulocyte                         0
# enteric smooth muscle cell                      0
# Name: count, Length: 698, dtype: int64

# %%
heart_obs[["tissue"]].value_counts()
# Out:
# tissue
# heart left ventricle       629658
# heart right ventricle      262024
# interventricular septum    259436
# heart                      112532
# apex of heart              110365
#                             ...
# gonad                           0
# gingiva                         0
# gastrocnemius                   0
# ganglionic eminence             0
# hindgut                         0
# Name: count, Length: 267, dtype: int64

# %%
heart_obs[["self_reported_ethnicity"]].value_counts()
# Out:
# self_reported_ethnicity
# European                                                                1336016
# unknown                                                                  169212
# Asian                                                                     32458
# Hispanic or Latin American                                                11505
# Han Chinese                                                               10783
# African American or Afro-Caribbean                                            0
# American                                                                      0
# British                                                                       0
# Bangladeshi                                                                   0
# East Asian                                                                    0
# Chinese                                                                       0
# European American                                                             0
# European,Asian                                                                0
# African American                                                              0
# African                                                                       0
# Greater Middle Eastern  (Middle Eastern or North African or Persian)          0
# Finnish                                                                       0
# Irish                                                                         0
# Iraqi                                                                         0
# Jewish Israeli                                                                0
# Korean                                                                        0
# Native American                                                               0
# Japanese                                                                      0
# Native American,Hispanic or Latin American                                    0
# Oceanian                                                                      0
# Singaporean Chinese                                                           0
# Pacific Islander                                                              0
# Singaporean Indian                                                            0
# Singaporean Malay                                                             0
# South Asian                                                                   0
# South East Asian                                                              0
# Name: count, dtype: int64

# %%
heart_obs[["donor_id"]].value_counts()
# Out:
# donor_id
# D6                       79650
# D11                      48931
# D2                       43143
# H5                       38401
# D7                       36134
#                          ...
# Control_Participant2         0
# Control_Participant19        0
# Control_Participant18        0
# Control_Participant17        0
# Control_Participant9         0
# Name: count, Length: 6603, dtype: int64

# %% [markdown]
# # Adding dataset information

# %% [markdown]
# ## Collection of dataset information

# %%
census_datasets = (
    census["census_info"]["datasets"]
    .read(column_names=["collection_name", "dataset_title", "dataset_id", "soma_joinid"])
    .concat()
    .to_pandas()
)
census_datasets = census_datasets.set_index("dataset_id")
census_datasets
# Out:
#                                                                         collection_name  \
# dataset_id
# 0895c838-e550-48a3-a777-dbcd35d30272  Single-Cell, Single-Nucleus, and Spatial RNA S...
# 00ff600e-6e2e-4d76-846f-0eec4f0ae417  Single-cell analysis of human B cell maturatio...
# bdacc907-7c26-419f-8808-969eab3ca2e8  Molecular characterization of selectively vuln...
# a5d95a42-0137-496f-8a60-101e17f263c8  Single-cell Atlas of common variable immunodef...
# d3566d6a-a455-4a15-980f-45eb29114cab  Single-cell proteo-genomic reference maps of t...
# ...                                                                                 ...
# 0bce33ed-455c-4e12-93f8-b7b04a2de4a1  A single-cell transcriptional timelapse of mou...
# c2876b1b-06d8-4d96-a56b-5304f815b99a  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# dcfa2614-7ca7-4d82-814c-350626eccb26  A single-cell transcriptional timelapse of mou...
# dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3  A single-cell transcriptional timelapse of mou...
#
#                                                                           dataset_title  \
# dataset_id
# 0895c838-e550-48a3-a777-dbcd35d30272                       Healthy human liver: B cells
# 00ff600e-6e2e-4d76-846f-0eec4f0ae417               Human tonsil nonlymphoid cells scRNA
# bdacc907-7c26-419f-8808-969eab3ca2e8  Molecular characterization of selectively vuln...
# a5d95a42-0137-496f-8a60-101e17f263c8                   Steady-state B cells - scRNA-seq
# d3566d6a-a455-4a15-980f-45eb29114cab   blood and bone marrow from a healthy young donor
# ...                                                                                 ...
# 0bce33ed-455c-4e12-93f8-b7b04a2de4a1                 Whole dataset: Normalized subset 2
# c2876b1b-06d8-4d96-a56b-5304f815b99a  Whole Taxonomy - MTG: Seattle Alzheimer's Dise...
# 6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3  Whole Taxonomy - DLPFC: Seattle Alzheimer's Di...
# dcfa2614-7ca7-4d82-814c-350626eccb26                       Major cell cluster: Mesoderm
# dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3                     Whole dataset: Raw counts only
#
#                                       soma_joinid
# dataset_id
# 0895c838-e550-48a3-a777-dbcd35d30272            0
# 00ff600e-6e2e-4d76-846f-0eec4f0ae417            1
# bdacc907-7c26-419f-8808-969eab3ca2e8            2
# a5d95a42-0137-496f-8a60-101e17f263c8            3
# d3566d6a-a455-4a15-980f-45eb29114cab            4
# ...                                           ...
# 0bce33ed-455c-4e12-93f8-b7b04a2de4a1          807
# c2876b1b-06d8-4d96-a56b-5304f815b99a          808
# 6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3          809
# dcfa2614-7ca7-4d82-814c-350626eccb26          810
# dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3          811
#
# [812 rows x 3 columns]

# %% [markdown]
# ## Addition of dataset information to our heart data

# %%
dataset_cell_counts = pd.DataFrame(heart_obs[["dataset_id"]].value_counts())
dataset_cell_counts = dataset_cell_counts.rename(columns={0: "cell_counts"})
dataset_cell_counts = dataset_cell_counts.merge(census_datasets, on="dataset_id")

dataset_cell_counts
# Out:
#                                        count  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  665955
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e  486134
# 1c739a3e-c3f5-49d5-98e0-73975e751201  191795
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353  101749
# 4ed927e9-c099-49af-b8ce-a2652d069333   36574
# ...                                      ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2       0
# 5829c7ba-697f-418e-8b98-d605b192dc48       0
# 58679288-9ecc-4647-9781-12a3a8f8c6fd       0
# 58c43cc2-e00e-43c4-94eb-8501369264e1       0
# 53bc5729-6202-4351-bc99-1f36139e9dc4       0
#
#                                                                         collection_name  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  Pathogenic variants damage cell composition an...
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e                     Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  Spatial multi-omic map of human myocardial inf...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353        A human cell atlas of fetal gene expression
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# ...                                                                                 ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2  HTAN MSK - Single cell profiling reveals novel...
# 5829c7ba-697f-418e-8b98-d605b192dc48  Single-cell genomic profiling of human dopamin...
# 58679288-9ecc-4647-9781-12a3a8f8c6fd  Spatiotemporal analysis of human intestinal de...
# 58c43cc2-e00e-43c4-94eb-8501369264e1  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 53bc5729-6202-4351-bc99-1f36139e9dc4  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
#
#                                                                           dataset_title  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039                DCM/ACM heart cell atlas: All cells
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e               All — Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  All-snRNA-Spatial multi-omic map of human myoc...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353              Survey of human embryonic development
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# ...                                                                                 ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2                                   Combined samples
# 5829c7ba-697f-418e-8b98-d605b192dc48               Human Oligodendrocytes 10x scRNA-seq
# 58679288-9ecc-4647-9781-12a3a8f8c6fd  Spatiotemporal analysis of human intestinal de...
# 58c43cc2-e00e-43c4-94eb-8501369264e1  OPC - DLPFC: Seattle Alzheimer's Disease Atlas...
# 53bc5729-6202-4351-bc99-1f36139e9dc4  Vip - DLPFC: Seattle Alzheimer's Disease Atlas...
#
#                                       soma_joinid
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039          776
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e          719
# 1c739a3e-c3f5-49d5-98e0-73975e751201          674
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353          799
# 4ed927e9-c099-49af-b8ce-a2652d069333          644
# ...                                           ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2          650
# 5829c7ba-697f-418e-8b98-d605b192dc48          616
# 58679288-9ecc-4647-9781-12a3a8f8c6fd           55
# 58c43cc2-e00e-43c4-94eb-8501369264e1          482
# 53bc5729-6202-4351-bc99-1f36139e9dc4          688
#
# [678 rows x 4 columns]

# %% [markdown]
# # Adding gene information

# %% [markdown]
# ## Collection of gene information for all Human

# %%
all_var = cellxgene_census.get_var(census, "homo_sapiens")
all_var
# Out:
#        soma_joinid       feature_id       feature_name  feature_length  \
# 0                0  ENSG00000000003             TSPAN6            4530
# 1                1  ENSG00000000005               TNMD            1476
# 2                2  ENSG00000000419               DPM1            9276
# 3                3  ENSG00000000457              SCYL3            6883
# 4                4  ENSG00000000460           C1orf112            5970
# ...            ...              ...                ...             ...
# 60525        60525  ENSG00000288718  ENSG00000288718.1            1070
# 60526        60526  ENSG00000288719  ENSG00000288719.1            4252
# 60527        60527  ENSG00000288724  ENSG00000288724.1             625
# 60528        60528  ENSG00000290791  ENSG00000290791.1            3612
# 60529        60529  ENSG00000290146  ENSG00000290146.1            1292
#
#             nnz  n_measured_obs
# 0       4530448        73855064
# 1        236059        61201828
# 2      17576462        74159149
# 3       9117322        73988868
# 4       6287794        73636201
# ...         ...             ...
# 60525         4         1248980
# 60526      2826         1248980
# 60527        36         1248980
# 60528      1642           43485
# 60529      7958           43485
#
# [60530 rows x 6 columns]

# %% [markdown]
# ## Collection of gene information specific to our dataset based on 'soma_joinid'

# %%
presence_matrix = cellxgene_census.get_presence_matrix(census, "Homo sapiens", "RNA")
presence_matrix = presence_matrix[dataset_cell_counts.soma_joinid, :]

# %%
presence_matrix.sum(axis=1).A1
# Out:
# array([30731, 31222, 28941, 44067, 29553, 27408, 20691, 56926, 26392,
#        30996, 27705, 28599, 27393, 25576, 25246, 33741,   458, 46621,
#        17538, 22372, 14446, 28244, 31312, 35385, 26265, 25431, 24646,
#        55880, 40956, 39447, 28418, 26595, 43001, 35061, 23079, 33599,
#        24981, 38618, 30716, 26588, 17374, 20191, 25680, 15407, 23659,
#        40226, 42852, 25546, 30357, 30469, 33936, 46139, 35899, 22177,
#        43525, 21194, 25315, 22779, 22392, 45463, 41821, 25295, 38541,
#        56350, 30800, 33212, 24647, 35489, 33945, 25983, 27074, 36616,
#        40773, 22288, 23658, 23172, 25022, 28588, 26187, 15979, 37854,
#        23798, 45369, 25311, 33596, 26418, 21007, 34601, 21196, 19550,
#        42410, 17104, 45530, 26624, 26365, 23586, 32622, 48704, 34480,
#        46983, 27807, 52115, 34468, 34052, 28186, 24965, 42094, 20267,
#        21908, 55818, 34078, 22643, 45950, 49063, 20901, 32391, 20982,
#        51489, 25342,  3420, 41464, 29497, 18252, 42549, 35468, 32121,
#        41775, 23493, 41391, 20941, 26929, 35107, 33844, 43275, 26034,
#        22979, 43963, 47837, 24710, 40507, 13715, 39468, 22687, 21160,
#        34268, 28083, 42597, 37838, 35849, 41366, 19149, 23537, 10999,
#        20854, 34468, 29057, 28372, 35243, 27638, 28046, 27054, 26107,
#        34681, 41661, 24446, 24533, 50205, 42756, 31515, 29067, 42459,
#        34951, 54580, 40433, 31826, 29898, 20803, 42164, 28640, 38225,
#        29261, 40967, 42882, 31450, 28433, 25228, 30006, 18881, 26046,
#        33767, 23143, 46984, 28000, 26756, 20525, 20768, 27633, 29015,
#        41052, 49522, 27244, 33229, 41067, 41628, 23407, 14853, 27369,
#        28949, 42176, 28871, 22668, 33531, 20627, 24726, 18911, 50768,
#        25638, 24062, 42019, 29073, 41601, 40993, 23686, 25196, 41275,
#        31720, 23948, 20712, 37157, 30991, 31853, 25306, 42519, 24937,
#        29332, 51579, 40967, 27125, 20299, 40678, 44147, 41016, 42631,
#        19551, 17647, 41788, 42418, 15216, 27737, 22503, 32899, 36283,
#        24256, 27957, 26397, 25810, 14405, 20964, 34014, 20879, 42790,
#        30979, 34257, 31265, 27979, 20822, 41753, 27401, 43178, 33780,
#        25663,   460, 26048, 23587, 21808, 39293, 42167, 37043, 42342,
#        24749, 27229, 23045, 26833, 24759, 38378, 28675, 24742, 27438,
#        14803, 36619,   461, 27721, 30557, 27991, 19698, 26013, 40072,
#        50694, 20043, 44866, 34626, 25045, 25215, 22806, 27579, 31430,
#        30884, 19330, 22093, 54349, 47207, 31234, 44391, 42490, 25712,
#        20938, 22429, 18651, 33833, 45222, 22018, 41951, 30431, 42984,
#        17755, 28164, 42966, 34569, 34170, 34725, 30260, 21586, 18495,
#        22264, 22629, 40956, 25905, 24085, 20383, 26889, 42261, 43215,
#        26781, 32402, 24618, 28807, 43472, 30679, 18269, 25924, 28391,
#        41473, 29784, 39689, 29433, 43424, 28605, 36557, 23650, 27919,
#        30511, 29140, 26794, 33931, 41821, 23161, 17797, 23467, 40491,
#        23040, 21604, 41114, 16795, 44528, 24323, 38843, 17797, 25213,
#        29986, 26414, 36755, 26071, 19530, 26660, 23513, 19554, 27718,
#        48309, 29039, 23143, 33912, 25683, 21110, 31405, 29675, 26279,
#        26263, 23593, 27830, 42597, 27476, 43723, 31285, 21789, 25730,
#        27132, 19884, 27561, 24264, 23694, 43115, 24015, 27167, 23127,
#        33139, 24397, 40015, 27598, 40425, 36642, 45265, 22018, 26094,
#        39173, 47001, 26760, 18406, 24900, 27957, 25541, 23190, 32847,
#        29889, 29361, 40844, 53235, 13696, 38935, 31593, 41034, 27079,
#        29393, 39658, 19917, 34455, 33949, 26448, 26231, 33822, 30075,
#        28548, 33117, 41374, 20942, 22912, 18175, 34805, 29381, 34500,
#        47719, 38606, 27992, 38542, 22321, 40480, 21095, 28716, 25508,
#         6438, 31811, 24183, 34173, 26987, 42156, 42604, 30662, 28097,
#        19033, 42806, 26403, 39264, 27100, 17109, 23306, 21221, 42181,
#        32525, 33310, 48270, 19193, 46597, 49341, 32270, 30045, 33295,
#        34277, 36231, 23930, 23177, 25264, 33363, 26029, 28615, 43092,
#        40673, 23098, 24465, 24449, 27984, 26186, 35893, 38496, 16041,
#        42530, 42120, 20941, 28928, 20093, 25771, 41792, 47779, 19093,
#        26028, 26087, 30055, 34176, 26205, 33684, 20448, 22125, 27310,
#        22211, 34725, 22117, 35473, 39684, 41817, 43597, 18643, 21190,
#        42616, 26951, 14311, 29260, 33380, 26063, 23821, 40459, 33643,
#        29754, 42789, 27681, 31356, 17465, 20556, 26561, 30330, 24532,
#         3882, 24888, 23934, 38070, 27636, 19485, 29453, 24325, 23987,
#        28617, 25740, 28451, 22492, 28071, 31293, 27711, 21001, 43449,
#        10945, 28889, 17758, 34151, 25040, 45541, 28535, 17449, 21664,
#        26253, 42616, 40697, 41657, 25189, 43132, 30656, 34607, 43817,
#        27376, 40415, 19019, 23660, 21962, 21330, 25707, 22823, 24832,
#        42113, 14755, 29194, 44272, 16986, 26894, 50925, 27323, 34009,
#        33070, 24669, 41529, 38997, 43528, 42997, 20188, 23610, 23535,
#        42510, 19458, 35144, 42007, 43101, 32678, 43049, 33626, 25460,
#        41385, 30790, 19245, 21516, 39535, 24814, 42311, 41707, 22826,
#        51484, 41672, 33411, 19467, 25328, 44694, 24893, 20753, 24592,
#        24667, 28072, 42022, 46605, 26037, 35122, 17757, 23172, 31033,
#        25920, 19356, 22493, 41806, 44674, 42099, 33258, 20424, 26615,
#        29526, 15166, 49271, 42457, 26302, 30079, 27299, 22397, 31118,
#        20649, 33253, 34779], dtype=uint64)

# %%
genes_measured = presence_matrix.sum(axis=1).A1
dataset_cell_counts["genes_measured"] = genes_measured
dataset_cell_counts
# Out:
#                                        count  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  665955
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e  486134
# 1c739a3e-c3f5-49d5-98e0-73975e751201  191795
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353  101749
# 4ed927e9-c099-49af-b8ce-a2652d069333   36574
# ...                                      ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2       0
# 5829c7ba-697f-418e-8b98-d605b192dc48       0
# 58679288-9ecc-4647-9781-12a3a8f8c6fd       0
# 58c43cc2-e00e-43c4-94eb-8501369264e1       0
# 53bc5729-6202-4351-bc99-1f36139e9dc4       0
#
#                                                                         collection_name  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  Pathogenic variants damage cell composition an...
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e                     Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  Spatial multi-omic map of human myocardial inf...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353        A human cell atlas of fetal gene expression
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# ...                                                                                 ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2  HTAN MSK - Single cell profiling reveals novel...
# 5829c7ba-697f-418e-8b98-d605b192dc48  Single-cell genomic profiling of human dopamin...
# 58679288-9ecc-4647-9781-12a3a8f8c6fd  Spatiotemporal analysis of human intestinal de...
# 58c43cc2-e00e-43c4-94eb-8501369264e1  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 53bc5729-6202-4351-bc99-1f36139e9dc4  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
#
#                                                                           dataset_title  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039                DCM/ACM heart cell atlas: All cells
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e               All — Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  All-snRNA-Spatial multi-omic map of human myoc...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353              Survey of human embryonic development
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# ...                                                                                 ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2                                   Combined samples
# 5829c7ba-697f-418e-8b98-d605b192dc48               Human Oligodendrocytes 10x scRNA-seq
# 58679288-9ecc-4647-9781-12a3a8f8c6fd  Spatiotemporal analysis of human intestinal de...
# 58c43cc2-e00e-43c4-94eb-8501369264e1  OPC - DLPFC: Seattle Alzheimer's Disease Atlas...
# 53bc5729-6202-4351-bc99-1f36139e9dc4  Vip - DLPFC: Seattle Alzheimer's Disease Atlas...
#
#                                       soma_joinid  genes_measured
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039          776           30731
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e          719           31222
# 1c739a3e-c3f5-49d5-98e0-73975e751201          674           28941
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353          799           44067
# 4ed927e9-c099-49af-b8ce-a2652d069333          644           29553
# ...                                           ...             ...
# 576f193c-75d0-4a11-bd25-8676587e6dc2          650           22397
# 5829c7ba-697f-418e-8b98-d605b192dc48          616           31118
# 58679288-9ecc-4647-9781-12a3a8f8c6fd           55           20649
# 58c43cc2-e00e-43c4-94eb-8501369264e1          482           33253
# 53bc5729-6202-4351-bc99-1f36139e9dc4          688           34779
#
# [678 rows x 5 columns]

# %% [markdown]
# ## Filtering genes matching our soma_joinid

# %%
heart_var =  all_var[all_var['soma_joinid'].isin(dataset_cell_counts['soma_joinid'])]
heart_var
# Out:
#      soma_joinid       feature_id feature_name  feature_length       nnz  \
# 0              0  ENSG00000000003       TSPAN6            4530   4530448
# 1              1  ENSG00000000005         TNMD            1476    236059
# 2              2  ENSG00000000419         DPM1            9276  17576462
# 3              3  ENSG00000000457        SCYL3            6883   9117322
# 4              4  ENSG00000000460     C1orf112            5970   6287794
# ..           ...              ...          ...             ...       ...
# 799          799  ENSG00000059728         MXD1            6351  16245940
# 801          801  ENSG00000059769      DNAJC25            2604   7161442
# 803          803  ENSG00000059915          PSD            5979  11487910
# 808          808  ENSG00000060339        CCAR1            6059  25400719
# 809          809  ENSG00000060491         OGFR            4702  16419108
#
#      n_measured_obs
# 0          73855064
# 1          61201828
# 2          74159149
# 3          73988868
# 4          73636201
# ..              ...
# 799        74218366
# 801        71248640
# 803        73984771
# 808        73988868
# 809        73988868
#
# [678 rows x 6 columns]

# %% [markdown]
# # Fetching all human heart data from the Census

# %%
heart_sample_ids = heart_obs["soma_joinid"].to_numpy()
heart_gene_ids = heart_var["soma_joinid"].to_numpy()

# %%
heart_adata = cellxgene_census.get_anndata(
    census,
    organism="Homo sapiens",
    obs_coords=heart_sample_ids,
    var_coords=heart_gene_ids  
)

heart_adata
# Out:
# AnnData object with n_obs × n_vars = 1559974 × 678
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
heart_adata.obs
# Out:
#          soma_joinid                            dataset_id        assay  \
# 0            1702855  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 1            1702856  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 2            1702857  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 3            1702858  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# 4            1702859  f15e263b-6544-46cb-a46e-e33ab7ce8347    10x 3' v3
# ...              ...                                   ...          ...
# 1559969     66344455  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559970     66344456  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559971     66344457  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559972     66344458  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
# 1559973     66344459  f7c1c579-2dc0-47e2-ba19-8165c5a0e353  sci-RNA-seq
#
#         assay_ontology_term_id                          cell_type  \
# 0                  EFO:0009922      immature innate lymphoid cell
# 1                  EFO:0009922       fibroblast of cardiac tissue
# 2                  EFO:0009922       fibroblast of cardiac tissue
# 3                  EFO:0009922      immature innate lymphoid cell
# 4                  EFO:0009922            cardiac muscle myoblast
# ...                        ...                                ...
# 1559969            EFO:0010550                cardiac muscle cell
# 1559970            EFO:0010550                cardiac muscle cell
# 1559971            EFO:0010550                cardiac muscle cell
# 1559972            EFO:0010550  endothelial cell of vascular tree
# 1559973            EFO:0010550                cardiac muscle cell
#
#         cell_type_ontology_term_id                         development_stage  \
# 0                       CL:0001082                   61-year-old human stage
# 1                       CL:0002548                   61-year-old human stage
# 2                       CL:0002548                   61-year-old human stage
# 3                       CL:0001082                   61-year-old human stage
# 4                       CL:0000513                   61-year-old human stage
# ...                            ...                                       ...
# 1559969                 CL:0000746  12th week post-fertilization human stage
# 1559970                 CL:0000746  12th week post-fertilization human stage
# 1559971                 CL:0000746  12th week post-fertilization human stage
# 1559972                 CL:0002139  12th week post-fertilization human stage
# 1559973                 CL:0000746  12th week post-fertilization human stage
#
#         development_stage_ontology_term_id                disease  \
# 0                           HsapDv:0000155  myocardial infarction
# 1                           HsapDv:0000155  myocardial infarction
# 2                           HsapDv:0000155  myocardial infarction
# 3                           HsapDv:0000155  myocardial infarction
# 4                           HsapDv:0000155  myocardial infarction
# ...                                    ...                    ...
# 1559969                     HsapDv:0000049                 normal
# 1559970                     HsapDv:0000049                 normal
# 1559971                     HsapDv:0000049                 normal
# 1559972                     HsapDv:0000049                 normal
# 1559973                     HsapDv:0000049                 normal
#
#         disease_ontology_term_id  ...                tissue  \
# 0                  MONDO:0005068  ...  heart left ventricle
# 1                  MONDO:0005068  ...  heart left ventricle
# 2                  MONDO:0005068  ...  heart left ventricle
# 3                  MONDO:0005068  ...  heart left ventricle
# 4                  MONDO:0005068  ...  heart left ventricle
# ...                          ...  ...                   ...
# 1559969             PATO:0000461  ...                 heart
# 1559970             PATO:0000461  ...                 heart
# 1559971             PATO:0000461  ...                 heart
# 1559972             PATO:0000461  ...                 heart
# 1559973             PATO:0000461  ...                 heart
#
#          tissue_ontology_term_id tissue_type tissue_general  \
# 0                 UBERON:0002084      tissue          heart
# 1                 UBERON:0002084      tissue          heart
# 2                 UBERON:0002084      tissue          heart
# 3                 UBERON:0002084      tissue          heart
# 4                 UBERON:0002084      tissue          heart
# ...                          ...         ...            ...
# 1559969           UBERON:0000948      tissue          heart
# 1559970           UBERON:0000948      tissue          heart
# 1559971           UBERON:0000948      tissue          heart
# 1559972           UBERON:0000948      tissue          heart
# 1559973           UBERON:0000948      tissue          heart
#
#         tissue_general_ontology_term_id raw_sum   nnz raw_mean_nnz  \
# 0                        UBERON:0000948  4190.0  2093     2.001911
# 1                        UBERON:0000948  6506.0  2750     2.365818
# 2                        UBERON:0000948  2462.0  1420     1.733803
# 3                        UBERON:0000948  1524.0  1067     1.428304
# 4                        UBERON:0000948  6199.0  2001     3.097951
# ...                                 ...     ...   ...          ...
# 1559969                  UBERON:0000948   633.0   485     1.305155
# 1559970                  UBERON:0000948   502.0   349     1.438395
# 1559971                  UBERON:0000948   459.0   364     1.260989
# 1559972                  UBERON:0000948   247.0   220     1.122727
# 1559973                  UBERON:0000948   347.0   276     1.257246
#
#         raw_variance_nnz n_measured_vars
# 0              12.914910           20691
# 1              41.999268           20691
# 2              23.365312           20691
# 3               3.061224           20691
# 4             387.196401           20691
# ...                  ...             ...
# 1559969         1.369498           44067
# 1559970         1.953809           44067
# 1559971         0.964755           44067
# 1559972         0.190349           44067
# 1559973         0.824493           44067
#
# [1559974 rows x 28 columns]

# %%
heart_adata.var
# Out:
#      soma_joinid       feature_id feature_name  feature_length       nnz  \
# 0              0  ENSG00000000003       TSPAN6            4530   4530448
# 1              1  ENSG00000000005         TNMD            1476    236059
# 2              2  ENSG00000000419         DPM1            9276  17576462
# 3              3  ENSG00000000457        SCYL3            6883   9117322
# 4              4  ENSG00000000460     C1orf112            5970   6287794
# ..           ...              ...          ...             ...       ...
# 673          799  ENSG00000059728         MXD1            6351  16245940
# 674          801  ENSG00000059769      DNAJC25            2604   7161442
# 675          803  ENSG00000059915          PSD            5979  11487910
# 676          808  ENSG00000060339        CCAR1            6059  25400719
# 677          809  ENSG00000060491         OGFR            4702  16419108
#
#      n_measured_obs
# 0          73855064
# 1          61201828
# 2          74159149
# 3          73988868
# 4          73636201
# ..              ...
# 673        74218366
# 674        71248640
# 675        73984771
# 676        73988868
# 677        73988868
#
# [678 rows x 6 columns]

# %%
filtered_data = dataset_cell_counts[dataset_cell_counts.index.isin(heart_adata.obs['dataset_id'])]

filtered_data
# Out:
#                                        count  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  665955
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e  486134
# 1c739a3e-c3f5-49d5-98e0-73975e751201  191795
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353  101749
# 4ed927e9-c099-49af-b8ce-a2652d069333   36574
# 5500c673-1610-40a0-86d9-64d987ae50e6   30889
# f15e263b-6544-46cb-a46e-e33ab7ce8347   19722
# 53d208b0-2cfd-4366-9866-c3c6114081bc   16372
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf   10783
# d567b692-c374-4628-a508-8008f6778f22       1
#
#                                                                         collection_name  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  Pathogenic variants damage cell composition an...
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e                     Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  Spatial multi-omic map of human myocardial inf...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353        A human cell atlas of fetal gene expression
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# 5500c673-1610-40a0-86d9-64d987ae50e6  Integrated adult and foetal heart single-cell ...
# f15e263b-6544-46cb-a46e-e33ab7ce8347  Spatial multi-omic map of human myocardial inf...
# 53d208b0-2cfd-4366-9866-c3c6114081bc                                     Tabula Sapiens
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  Construction of a human cell landscape at sing...
# d567b692-c374-4628-a508-8008f6778f22  Spatially resolved multiomics of human cardiac...
#
#                                                                           dataset_title  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039                DCM/ACM heart cell atlas: All cells
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e               All — Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  All-snRNA-Spatial multi-omic map of human myoc...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353              Survey of human embryonic development
# 4ed927e9-c099-49af-b8ce-a2652d069333  Single-nucleus cross-tissue molecular referenc...
# 5500c673-1610-40a0-86d9-64d987ae50e6                 Integrated adult and foetal hearts
# f15e263b-6544-46cb-a46e-e33ab7ce8347  Ischemia-snRNA-Spatial multi-omic map of human...
# 53d208b0-2cfd-4366-9866-c3c6114081bc                         Tabula Sapiens - All Cells
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  Construction of a human cell landscape at sing...
# d567b692-c374-4628-a508-8008f6778f22  Combined single cell and single nuclei RNA-Seq...
#
#                                       soma_joinid  genes_measured
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039          776           30731
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e          719           31222
# 1c739a3e-c3f5-49d5-98e0-73975e751201          674           28941
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353          799           44067
# 4ed927e9-c099-49af-b8ce-a2652d069333          644           29553
# 5500c673-1610-40a0-86d9-64d987ae50e6          442           27408
# f15e263b-6544-46cb-a46e-e33ab7ce8347          233           20691
# 53d208b0-2cfd-4366-9866-c3c6114081bc          785           56926
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf          642           26392
# d567b692-c374-4628-a508-8008f6778f22          760           30996

# %%
heart_adata.obs = heart_adata.obs.merge(filtered_data, left_on='dataset_id', right_index=True, how='left')

heart_adata
# Out:
# AnnData object with n_obs × n_vars = 1559974 × 678
#     obs: 'soma_joinid_x', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars', 'count', 'collection_name', 'dataset_title', 'soma_joinid_y', 'genes_measured'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
heart_adata.obs['collection_name'].value_counts()
# Out:
# collection_name
# Pathogenic variants damage cell composition and single cell transcription in cardiomyopathies    665955
# Cells of the adult human heart                                                                   486134
# Spatial multi-omic map of human myocardial infarction                                            211517
# A human cell atlas of fetal gene expression                                                      101749
# Single-nucleus cross-tissue molecular reference maps to decipher disease gene function            36574
# Integrated adult and foetal heart single-cell RNA sequencing                                      30889
# Tabula Sapiens                                                                                    16372
# Construction of a human cell landscape at single-cell level                                       10783
# Spatially resolved multiomics of human cardiac niches                                                 1
# Name: count, dtype: int64

# %%
heart_adata.obs['dataset_title'].value_counts()
# Out:
# dataset_title
# DCM/ACM heart cell atlas: All cells                                                       665955
# All — Cells of the adult human heart                                                      486134
# All-snRNA-Spatial multi-omic map of human myocardial infarction                           191795
# Survey of human embryonic development                                                     101749
# Single-nucleus cross-tissue molecular reference maps to decipher disease gene function     36574
# Integrated adult and foetal hearts                                                         30889
# Ischemia-snRNA-Spatial multi-omic map of human myocardial infarction                       19722
# Tabula Sapiens - All Cells                                                                 16372
# Construction of a human cell landscape at single-cell level                                10783
# Combined single cell and single nuclei RNA-Seq data - Heart Global                             1
# Name: count, dtype: int64

# %%
heart_adata.obs[['dataset_title','disease','suspension_type']].value_counts()
# Out:
# dataset_title                                                                           disease                                          suspension_type
# DCM/ACM heart cell atlas: All cells                                                     dilated cardiomyopathy                           nucleus            482581
# All — Cells of the adult human heart                                                    normal                                           nucleus            359652
# All-snRNA-Spatial multi-omic map of human myocardial infarction                         myocardial infarction                            nucleus            150132
# All — Cells of the adult human heart                                                    normal                                           cell               126482
# DCM/ACM heart cell atlas: All cells                                                     arrhythmogenic right ventricular cardiomyopathy  nucleus            104496
# Survey of human embryonic development                                                   normal                                           nucleus            101749
# DCM/ACM heart cell atlas: All cells                                                     normal                                           nucleus             67246
# All-snRNA-Spatial multi-omic map of human myocardial infarction                         normal                                           nucleus             41663
# Single-nucleus cross-tissue molecular reference maps to decipher disease gene function  normal                                           nucleus             36574
# Integrated adult and foetal hearts                                                      normal                                           cell                30889
# Ischemia-snRNA-Spatial multi-omic map of human myocardial infarction                    myocardial infarction                            nucleus             19722
# Tabula Sapiens - All Cells                                                              normal                                           cell                16372
# DCM/ACM heart cell atlas: All cells                                                     non-compaction cardiomyopathy                    nucleus             11632
# Construction of a human cell landscape at single-cell level                             normal                                           cell                10783
# Combined single cell and single nuclei RNA-Seq data - Heart Global                      normal                                           cell                    1
# Name: count, dtype: int64

# %% [markdown]
# ### Closing census

# %%
census.close()
del census

# %% [markdown]
# ## Data saving

# %%
heart_adata
# Out:
# AnnData object with n_obs × n_vars = 1559974 × 678
#     obs: 'soma_joinid_x', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'observation_joinid', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_type', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars', 'count', 'collection_name', 'dataset_title', 'soma_joinid_y', 'genes_measured'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
heart_adata.write(f'../cellxgene/data/cellxgene_heart_data_sk_{timestamp}.h5ad')
